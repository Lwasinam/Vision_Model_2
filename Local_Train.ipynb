# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

from train import train_model

train_model(cfg)
# Out:
# Using device: cpu
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 9
#       5 cfg['num_epochs'] = 30
#       7 from train import train_model
# ----> 9 train_model(cfg)
#
# File ~/AI_Projects/pytorch-transformer-main/train.py:188, in train_model(config)
#     185 # Make sure the weights folder exists
#     186 Path(config['model_folder']).mkdir(parents=True, exist_ok=True)
# --> 188 train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
#     189 model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)
#     190 # Tensorboard
#
# File ~/AI_Projects/pytorch-transformer-main/train.py:143, in get_ds(config)
#     141 def get_ds(config):
#     142     # It only has the train split, so we divide it overselves
# ...
